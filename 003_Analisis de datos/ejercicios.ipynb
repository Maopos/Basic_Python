# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.DataFrame({
    'name':['BBva','Davivienda','Popular','Colpatria','Caja Social','Hscbc','bbSuizo'],
    'sucursales':[234,178,322,119,245,533,420],
    'Tipo':['Privado','Publico','Publico','Privado','Publico','Publico','Privado'],
    'Pais':['Colombia','Argentina','Brasil','Colombia','Peru','Brasil','Colombia'],
    'Audiencias':[3, 6, 4, 6, 3, 8, 2],
    'Auditorias':[4, 2, 4, 5 ,3, 4, 1]
})

# %%
df
# Out:
#           name  sucursales     Tipo       Pais  Audiencias  Auditorias
# 0         BBva         234  Privado   Colombia           3           4
# 1   Davivienda         178  Publico  Argentina           6           2
# 2      Popular         322  Publico     Brasil           4           4
# 3    Colpatria         119  Privado   Colombia           6           5
# 4  Caja Social         245  Publico       Peru           3           3
# 5        Hscbc         533  Publico     Brasil           8           4
# 6      bbSuizo         420  Privado   Colombia           2           1

# %%
print(type(df.groupby('Audiencias')['name'].nunique()))
df.groupby('Pais')['name'].nunique().plot(kind='bar')

plt.show()
# Out:
# <class 'pandas.core.series.Series'>

# %%
Datos = [20,22,56, 63,68,32,89,21,20,23,25,28,40,22,23,22,15,16,18,18,19,21,22,24,4,12,17,17,22,30,]
Rangobin=[0,10,20,20,30,40, 50,60,70]
plt.hist(Datos, Rangobin, histtype='bar',rwidth=0.8, color='green')

plt.title('Clientes')
plt.ylabel('Cantidad')
plt.xlabel('Edades')
plt.grid()  
plt.show()
